# %% [markdown]
# # Starting my python journey

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # variables

# %%
#type of the assigned data
a=22
b=33.999
c="my"
print(type(c))
print(type(a))
print(type(b))
type(a)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# int

# %%
#another way of finding the data type and data stored or present(saved) in the memory
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      22
# b          float    33.999
# c          str      my

# %%
#multiple assign
a,b,c,d,e,=1,33.5,4444444444.000000000,"My name is debamitra barua",-33
# %whos
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      1
# b          float    33.5
# c          float    4444444444.0
# d          str      My name is debamitra barua
# e          int      -33
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'int'>

# %%
a= 3 + 33j
print(type(a))
# Out:
# <class 'complex'>

# %% [markdown]
# # delete

# %%
print(a)
del a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 print(a)
#       2 del a
#       3 print(a)
#
# NameError: name 'a' is not defined

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          complex    (3+33j)
# b          float      33.5
# c          float      4444444444.0
# d          str        My name is debamitra barua
# e          int        -33
# x          complex    (3+33j)

# %% [markdown]
# # operators

# %%
#addition
a=2
b=4
print(a+b)
#substaction
print(a-b)
#divison(decimal value as answer)
print(a/b)
#multiplication
print(a*b)
#remainder(mod)
print(a%b)
#floor divison(for int  value)
print(a//b)
#to the power
print(a**b)
# Out:
# 6
# -2
# 0.5
# 8
# 2
# 0
# 16

# %% [markdown]
# # adding two strings

# %%
s1="Hello "
s2="World"
print(s1+s2)
# Out:
# Hello World

# %%
3x=4 #cannot store number or special characters a variable (_underscore)
# Out:
#   Cell In[62], line 1
#     3x=4
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # comparison

# %%
a = int(input("Enter the number:"))
b = int(input("Enter the number:"))
if a>b  and a % 2==0:
    print ("the number a is is the greatest and even")
elif a>b and  a %  3==0:
    print("the number a is greatest and odd")
elif a<b and  b %  3==0:
    print("the number b is greatest and odd")
elif a<b and  a %  2==0:
    print("the number b is greatest and even")
else:
    print("the number's are invalid")
# Out:
# Enter the number: 55
# Enter the number: 6
# the number's are invalid

# %% [markdown]
# # Bool

# %%
a= True
b=False
c=True
print(a and b)
print(a and b)
print(a and c)
print(a and not(b)) #not changes the result to opposite
# Out:
# False
# False
# True
# True

# %%
#check
2==2.0
# Out:
# True

# %%
False or False and  True
# Out:
# False

# %%
print(not(2!=3)and  true) or (False and true)
# Out:
# False
# False

# %% [markdown]
# # round function

# %%
a=round(22.445,2)#after commma it will tell upto which decimall point
b=round(4.65)
print(a)
print(b)
# Out:
# 22.45
# 5

# %% [markdown]
# # divmod

# %%
divmod(22,2)#to get quotient and remainder
# Out:
# (11, 0)

# %% [markdown]
#  # isinstace

# %%
isinstance("a",(int,complex,float))
# Out:
# False

# %%
isinstance(2+3j,(int,str,float,complex))
# Out:
# True

# %% [markdown]
# # pow function

# %%
pow(2,3)
# Out:
# 8

# %%
pow(2,3,3)# first it will perform x**y then x**y % z and it will give the remainder
# Out:
# 2

# %% [markdown]
# # 1. find the bigger number

# %%
a=int(input("Enter  the Number a :"))
b=int(input("Enter  the Number b :"))
if (a>b):
    print("number a is bigger")
elif(b>a):
    print("number b is bigger")
else:
    print("Invalid Input")
# Out:
# Enter  the Number a : 3
# Enter  the Number b : 33
# number b is bigger

# %% [markdown]
# # multiple if-else

# %%
a=int(input("enter the number :"))
if(a>100):
    print("wow")
    if a % 2 == 0:
        print("even number")
    elif(a % 3 == 0):
        print("odd Number")
    else:
        print("Invalid")
else:
    print("Not wow")
# Out:
# enter the number : 399
# wow
# odd Number

# %%
### round of a number and the integer is even or not
a = float(input("Enter  the number :"))
b= (round(a))
print(b)
if(b % 2 == 0):
    print("Even number ")
else:
    print("odd number")
# Out:
# Enter  the number : 22.31
# 22
# Even number

# %% [markdown]
# # loop

# %%
#while loop
a=(int(input("Enter Here:")))
i = 1
while i <= a:
    print("Hi!")
    i += 2
# Out:
# Enter Here: 4
# Hi!
# Hi!

# %%
#for loop
for i in range(0,6,3):
    print("Debamitra")

# %%
#day-3
n = int(input("Enter the number :"))
i=1
while(i<=n):
    print("The number will be:", i)
    print(i**7)
    i+=1
    print("Done")
# Out:
# Enter the number : 3
# The number will be: 1
# 1
# Done
# The number will be: 2
# 128
# Done
# The number will be: 3
# 2187
# Done

# %% [markdown]
# # list

# %%
l = []
for i in range (0,10,2):
    print(i+1)
    l.append(i**2)
    print(l)
else:
    print("out")
# Out:
# 1
# [0]
# 3
# [0, 4]
# 5
# [0, 4, 16]
# 7
# [0, 4, 16, 36]
# 9
# [0, 4, 16, 36, 64]
# out

# %% [markdown]
# # functions

# %%
#resueable block of code by using the defined variable
#healthy way use: Docstring make it understandable abouut the function
#use ? and ?? for knowing about them
#help also same
def greetings():
    """greeting using this any part of the code """
    print("Hello")
    print("Hello")
    print("Hello")

greetings()
print("No hello")
greetings()
# Out:
# Hello
# Hello
# Hello
# No hello
# Hello
# Hello
# Hello

# %%
greetings()
# Out:
# Hello
# Hello
# Hello

# %%
greetings?
# Out:
# Signature: greetings()
# Docstring: greeting using this any part of the code
# File:      c:\users\rajpu\appdata\local\temp\ipykernel_11012\3661497895.py
# Type:      function

# %%
def printmsg(msg):
    """tells the user input is string or not!"""
    if isinstance(msg,str):
        print("The input is a string")
    else :
        print("Not a string")
        print("The given message:",msg)
printmsg(10)
# Out:
# Not a string
# The given message: 10

# %%
#use of function
def checkthenum(num):
    """checks the number is positive or negative """
    if num > 0:
        print("Positive Number")
    else:
        print("Negative Number")
        print("The number is",type(num))
checkthenum(-22)
# Out:
# Negative Number
# The number is <class 'int'>

# %%
#creating own power function
def letspow(a,b):
    """ this function is use to find a**b """
    c= a**b
    print("The Number a is :",a)
    print("The Number b is :",b)
    print("The answer is :",c)

# %%
letspow(2,3)
# Out:
# The Number a is : 2
# The Number b is : 3
# The answer is : 8

# %%
#use function tro use add to add x and y and print c
def mydd(x,y):
    c=x+y
    return c

# %%
a = mydd(2,3)
print("The number is :",a)
# Out:
# The number is : 5

# %%
def f(a,b,c):
    a=33
    b= 44.667
    c="debamitra"
    return a,b,c

# %%
str1= "Playz "
str2= "loves"
str3= "Niko "
final_str = str1 + str2 + str3
print("the statement is :", final_str)
print("length of the string:", len(final_str))
#can access only not manipulate
print(final_str[14])
#slicing
print(final_str[1:7])
# Out:
# the statement is : Playz lovesNiko
# length of the string: 16
# o
# layz l

# %% [markdown]
# # slicing of string

# %%
#positive slicing
a="mynameisdebamitra"
print(a[1:len(a)])
# Out:
# ynameisdebamitra

# %%
#negative slicing
a="nikodonalwayson"
print(a[-2:len(a)])
# Out:
# on

# %%
#endswith check
a="deba"
a.endswith("a")
# Out:
# True

# %%
a = a.capitalize() #capitalizes the first letter
print(a)
# Out:
# Deba

# %%
#replace
#print (a.replace("Deba", "Niko"))
#or
b= a.replace("Deba", "Don")
print(b)
# Out:
# Don

# %%
#find
a="my name is deba"
print(a.find(" "))
# Out:
# 2

# %%
#count(number of times it is present)
a="ooadkahdnacrrrrrrvvvvooooooaaaaanfksehfeikhf"
print(a.count("o"))
# Out:
# 8

# %%
#user input and find length of the string
a =str(input("Enter the string :" ))
print(len(a))
print(a.count("$"))
print(a.find("$"))
# Out:
# Enter the string : faxdafdgadja$$$
# 15
# 3
# 12

# %%
print(a.count("$"))
# Out:
# 0

# %%
#odd or even
c= int(input("Enter the numebr:"))
if c % 2 ==0 and c!=0:
    print("Even number")
elif c % 3 ==0 and c!=0:
    print("Odd number")
else:
    print("Invalid")
# Out:
# Enter the numebr: -2
# Even number

# %%
#find greatest among 3 input  numbers
a= int(input("Enter the numebr:"))
b= int(input("Enter the numebr:"))
c= int(input("Enter the numebr:"))
if a > b and a > c and a !=0 :
    print("a is the greatest among all")
elif b > a and b > b!=0  :
    print("b is the greatest among all")
elif c>a and c>b and c!=0:
    print("c is the greatest among all")
else:
    print("Invalid Input")
# Out:
# Enter the numebr: 0
# Enter the numebr: 0
# Enter the numebr: 0
# Invalid Input

# %%
#multiple of 7 or not
b= int(input("Enter the numebr:"))
if b % 7 == 0:
    print("Multiple of 7")
else:
    print("Not a multiple of 7")
# Out:
# Enter the numebr: 35
# Multiple of 7

# %%
import random
aim_number = random.randint(1, 100)
guess = 0

print("a number between 1 and 100.")

while guess != aim_number:
    guess = int(input("Enter guess: "))
    
    if guess < aim_number:
        print("Too low")
    elif guess > aim_number:
        print("Too high")
    else:
        print("You win:")
# Out:
# a number between 1 and 100.
# Enter your guess:  100
# Too high!
# Enter your guess:  5
# Too low!
# Enter your guess:  66
# Too low!
# Enter your guess:  77
# Too low!
# Enter your guess:  88
# Too low!
# Enter your guess:  98
# Too high!
# Enter your guess:  97
# Too high!
# Enter your guess:  92
# Too high!
# Enter your guess:  89
# Too low!
# Enter your guess:  90
# You win!
